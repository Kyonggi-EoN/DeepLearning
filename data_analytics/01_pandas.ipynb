# %% [markdown]
# # 판다스 배우기
#
# 판다스란? 데이터 분석을 진행하는 프로그래머들이 가장 많이 사용하는 파이썬 라이브러리 입니다.
#
# https://youtube.com/playlist?list=PLNPt2ycoheHrQHSg7MqTELiWUmieIxH-5&si=U3BvLLY-ZdSY7S6K
#
# 위 재생 목록을 보면서 판다스를 해봅시다
